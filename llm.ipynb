# %%
import torch
from bpe import BPETokenizer

if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

# %%
import urllib.request
import os
url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
file_path = "dataset.txt"

if not os.path.exists(file_path):
    urllib.request.urlretrieve(url, file_path)

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

# %%
TARGET_VOCAB = 512
tokenizer = BPETokenizer()
tokenizer.train(text, TARGET_VOCAB)

# %%
encoding = tokenizer.encode("Hello, my name is Szymon")
print(encoding)
decoding = tokenizer.decode(encoding)
print(decoding)
# Out:
# [[20, 43, 50, 50, 53], [6], [1, 51, 63], [1, 52, 39, 51, 43], [1, 47, 57], [1, 31, 64, 63, 51, 53, 52]]
# [[20, 218, 53], [6], [115], [89, 355], [133], [336, 64, 63, 51, 84]]
# Hello, my name is Szymon
